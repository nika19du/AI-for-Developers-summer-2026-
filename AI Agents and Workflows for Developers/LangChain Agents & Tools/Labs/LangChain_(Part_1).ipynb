# %% [markdown]
# <a href="https://colab.research.google.com/github/nika19du/AI-for-Developers-summer-2026-/blob/main/LangChain_(Part_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-anthropic langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.6 MB/s eta 0:00:00

# %%
from google.colab import userdata
from langchain.messages import AIMessage, HumanMessage, SystemMessage
from langchain_anthropic import ChatAnthropic
from langchain_openai import ChatOpenAI
from pydantic import SecretStr

def print_response(response: AIMessage):
    print(f"Response id: {response.id}")
    if response.usage_metadata is not None:
        input_tokens = response.usage_metadata.get("input_tokens", 0);
        cached_tokens = response.usage_metadata.get("input_token_details",{}).get("cache_read", 0)
        output_tokens = response.usage_metadata.get("output_tokens", 0)
        reasoning_tokens = response.usage_metadata.get("output_token_details", {}).get("reasoning", 0)

        print(f"Input tokens: {input_tokens} ({cached_tokens} cached); Output tokens: {output_tokens} ({reasoning_tokens} reasoning)")

    print()
    print(f"{'-' * 20} [Output] {'-' * 20}")
    print(response.text)

# %%
messages = [
    SystemMessage("You are a helpful history teaching assistant."),
    HumanMessage("Write a short museum audio-guide introduction for first-time visitors standing in front of the Rosetta Stone. Keep it under 5 sentences.")
]

# %%
openai_api_key = SecretStr(userdata.get('OPENAI_API_KEY'))
openai_model = ChatOpenAI(model = "gpt-5-nano", api_key = openai_api_key, reasoning_effort = "low")

# %%
museum_audio_guide_response = openai_model.invoke(
    input = messages
)

# %%
print_response(museum_audio_guide_response)
# Out:
# Response id: lc_run--01a015e0-4192-7de3-81f5-b48b067b1cef-0
# Input tokens: 45 (0 cached); Output tokens: 421 (320 reasoning)
#
# -------------------- [Output] --------------------
# Welcome to the Rosetta Stone, dating from 196 BCE during the Ptolemaic Kingdom. This tablet bears the same decree in three scripts—Greek, hieroglyphic, and Demotic—allowing scholars to read ancient Egyptian texts. By comparing the scripts, researchers unlocked a wealth of knowledge about pharaohs, temples, and daily life. As you listen, notice how a single inscription bridged languages across more than two millennia.

# %%
anthropic_api_key = SecretStr(userdata.get('ANTHROPIC_API_KEY'))
anthropic_model = ChatAnthropic(model = "claude-haiku-4-5", api_key=anthropic_api_key)

# %%
museum_audio_guide_response = anthropic_model.invoke(
    input = messages
)

# %%
print_response(museum_audio_guide_response)
# Out:
# Response id: lc_run--01a015e4-547d-7b70-b0bb-80a45d6de92d-0
# Input tokens: 46 (0 cached); Output tokens: 152 (0 reasoning)
#
# -------------------- [Output] --------------------
# # Welcome to the Rosetta Stone
#
# You're standing before one of history's most extraordinary objects. Discovered in Egypt in 1799, this granite slab unlocked an ancient mystery—it's inscribed with the same message in three different scripts, including Egyptian hieroglyphics, allowing scholars to finally decode a lost language. For nearly 2,000 years, no one could read the hieroglyphs that ancient Egyptians had carved into temples and tombs; this stone was the key. Today, it represents a triumph of human curiosity and our endless drive to understand civilizations long gone. Take a moment to appreciate how this single object transformed our knowledge of one of the world's greatest ancient cultures.
