# %% [markdown]
# <a href="https://colab.research.google.com/github/nika19du/AI-for-Developers-summer-2026-/blob/main/LangChain(Short_Term_memory).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 9.3 MB/s eta 0:00:00

# %%
from IPython.display import Image
from google.colab import userdata
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.tools import tool
from langchain_core.messages import BaseMessage
from langchain_core.runnables import Runnable
from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import InMemorySaver
from pathlib import Path
from pydantic import SecretStr
from typing import List

openai_api_key = SecretStr(userdata.get('OPENAI_API_KEY'))

def print_conversation(conversation: List[BaseMessage]):
    for message in conversation:
        message.pretty_print()

def display_graph(runnable: Runnable, output_png: Path) -> None:
    graph = runnable.get_graph()

    with output_png.open(mode = "wb") as file:
        file.write(graph.draw_mermaid_png())

    display(Image(output_png, format = "png"))

# %%
@tool
def get_interesting_fact() -> str:
    """
    This tool will discover an interesting fact to you.
    """

    return "The Earth is actually not a perfect sphere."

# %%
agent = create_agent(
    model = ChatOpenAI(model="gpt-5-nano", api_key = openai_api_key, reasoning_effort="low"),
    tools = [get_interesting_fact],
    checkpointer = InMemorySaver()
)

# %%
result1 = agent.invoke(
    input = {
        "messages": [HumanMessage("Hello, AI. My name is Nikol.")]
    },
    config = {
        "configurable": {
            "thread_id": "thread_1"
        }
    }
)

# %%
result1
# Out:
# {'messages': [HumanMessage(content='Hello, AI. My name is Nikol.', additional_kwargs={}, response_metadata={}, id='9f82a9b4-52b2-42ac-91ff-14ead1a74e4c'),
#   AIMessage(content='Hi Nikol! Nice to meet you. How can I help today? If you’d like, I can share an interesting fact, help with a project, answer questions, brainstorm ideas, practice a language, or anything else you have in mind.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 122, 'prompt_tokens': 133, 'total_tokens': 255, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EGj4Ae5TtOtj2vxqjsU0bmQI7A1gE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0388d-75fe-7f90-9875-d6d369cab23b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 133, 'output_tokens': 122, 'total_tokens': 255, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#   HumanMessage(content='Hello, AI. My name is Nikol.', additional_kwargs={}, response_metadata={}, id='7485d11b-9086-4340-8a79-73bd645ddf00'),
#   AIMessage(content='Hi Nikol! Nice to meet you again. How can I help you today? If you’d like, I can share an interesting fact, help with a project, answer questions, brainstorm ideas, practice a language, or chat about anything you have in mind.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 201, 'total_tokens': 262, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EGj58qDdMzyaYNAUGt9ApdikLLNjb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a0388e-5fd7-7813-9c70-64d6ad6b1ea1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 201, 'output_tokens': 61, 'total_tokens': 262, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
print_conversation(result1['messages'])
# Out:
# ================================ Human Message =================================
#
# Hello, AI. My name is Nikol.
# ================================== Ai Message ==================================
#
# Hi Nikol! Nice to meet you. How can I help today? If you’d like, I can share an interesting fact, help with a project, answer questions, brainstorm ideas, practice a language, or anything else you have in mind.
# ================================ Human Message =================================
#
# Hello, AI. My name is Nikol.
# ================================== Ai Message ==================================
#
# Hi Nikol! Nice to meet you again. How can I help you today? If you’d like, I can share an interesting fact, help with a project, answer questions, brainstorm ideas, practice a language, or chat about anything you have in mind.

# %%
result2 = agent.invoke(
    input = {
        "messages": [HumanMessage("Do you know my name")]
    },
    config = {
        "configurable": {
            "thread_id": "thread_1"
        }
    }
)

# %%
print_conversation(result2['messages'])
# Out:
# ================================ Human Message =================================
#
# Hello, AI. My name is Nikol.
# ================================== Ai Message ==================================
#
# Hi Nikol! Nice to meet you. How can I help today? If you’d like, I can share an interesting fact, help with a project, answer questions, brainstorm ideas, practice a language, or anything else you have in mind.
# ================================ Human Message =================================
#
# Hello, AI. My name is Nikol.
# ================================== Ai Message ==================================
#
# Hi Nikol! Nice to meet you again. How can I help you today? If you’d like, I can share an interesting fact, help with a project, answer questions, brainstorm ideas, practice a language, or chat about anything you have in mind.
# ================================ Human Message =================================
#
# Do you know my name
# ================================== Ai Message ==================================
#
# Yes, you told me your name is Nikol. How would you like me to address you, and what can I help with today?
