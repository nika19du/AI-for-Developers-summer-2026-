# %% [markdown]
# <a href="https://colab.research.google.com/github/nika19du/AI-for-Developers-summer-2026-/blob/main/Fine_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q openai

# %%
from pprint import pprint
from pydantic import BaseModel

def print_response(response):
  print(f"Response id: {response.id}")
  print(f"Input tokens: {response.usage.input_tokens} ({response.usage.input_tokens_details.cached_tokens} cached); Output tokens: {response.usage.output_tokens} ({response.usage.output_tokens_details.reasoning_tokens} reasoning)")
  pprint(response.output)

  print()
  print(f"{'-' * 20} [Text] {'-' * 20}")
  print(response.output_text)

# %%
from google.colab import userdata
from openai import OpenAI

api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

# %%
generate_course_name_response  = response = client.responses.create(
  prompt = {
    "id": "pmpt_6a5cb6140dfc8197997f3048268d727105df067717818e4e",
    "version": "3",
    "variables":{
      "description": "Базите данни са стандартният начин за използване на динамична информация в съвременните технологии, правейки ги неизменна част от почти всяко едно приложение. Интензивният курс по основи на базите данни ще запознаe с една от най-широко използваните системи за управление на бази данни (DBMS), използвани при разработката на съвременни информационни системи - PostgreSQL. Курсът обръща сериозно внимание на релационния модел, ER диаграмите (таблици и релационни връзки) и работата с езика SQL (извличане на данни, селекция, проекция, съединения, агрегация, групиране, промяна, изтриване и вмъкване). Предоставят се фундаментални знания за работа с функции, процедури, transactions и тригери. Този курс полага основите на работата с бази данни, правейки по-лесно използването им в реални приложения и разбирането на концепции като превръщане на база данни в обектно-ориентиран модел (ORM). Също така 30% от задачите на упражненията ще се решават с помощта на AI с цел да се стимулира използването на съвременни технологии за автоматизация на процеси, като същевременно се развиват умения за ефективно прилагане на AI инструменти в реални условия."
    }
  }
)

# %%
print_response(generate_course_name_response)
# Out:
# Response id: resp_00f78a6ade944410006a5cb93014f081a0a8170f5edb766fa8
# Input tokens: 487 (0 cached); Output tokens: 484 (448 reasoning)
# [ResponseReasoningItem(id='rs_00f78a6ade944410006a5cb930966c81a0b742c1aa2b9fc549', summary=[Summary(text='**Determining course name**\n\nI need to create a concise course name that captures the essence of a Bulgarian course on database fundamentals, PostgreSQL, SQL, ER diagrams, ORM, and AI integration. I have a few options like "Database Fundamentals with PostgreSQL and AI-Enhanced Applications." However, I want something shorter. I could go for "PostgreSQL Fundamentals and SQL for Modern Applications" or "Database Fundamentals and PostgreSQL for Modern Applications." Ultimately, “PostgreSQL Fundamentals for Modern Applications” seems clean and effective, covering the necessary content well!', type='summary_text'), Summary(text='**Choosing course name**\n\nI’m thinking about including SQL and ORM in the course title. Maybe "PostgreSQL and SQL for Modern Applications" could work, but “PostgreSQL Fundamentals” already suggests some SQL knowledge. I might settle on "PostgreSQL Fundamentals and SQL for Modern Applications." It’s descriptive, though a bit lengthy. I also consider "Databases Fundamentals with PostgreSQL and AI-Enhanced Practice." However, embedding AI in the name feels off. Ultimately, I\'ll go with "PostgreSQL Fundamentals for Modern Applications" since it clearly conveys the key focus.', type='summary_text'), Summary(text='**Finalizing course name**\n\nI’m considering a clearer course name: "PostgreSQL and SQL Fundamentals for Modern Applications." This title covers both PostgreSQL and SQL, which is essential. So, yeah, I’ll settle on "PostgreSQL and SQL Fundamentals for Modern Applications," making sure
NGaC6dE3yYx3EJOcptgzx1fsdPREpzX5RkGDPu7-Lbl9zd7IEZVZAOtW2Lasv8ggOrJWG93TbLNe6Tjv_1rRyQk4xG0aaTll13NCTae7mAlplpVs8StHhpoLqv0LfsmqwxwaJuyo_wLgy8rYWNH3jxYZS7SP5JiTRa32Umkdc3yjnjosNPagdoOf8qA8JUUNyx_wWE5F7KfiRmvJK6f3bhyhfwROLC5xXsehV4_jrznldM4vQsHBMkXX1A-3rG15ZNWoULPUOAOkJ_fP5y9Hm--oKe_vDZdVuLNxuekWstSqZzArnAVYZIfnzb9r97qUV0U293obllOgd_Wkx3hZ4bhY4cHjod_4lH-KCA4WmTgsL9KHKuZk-Cp_k3XTaWUtEdNB1tWbKAR4Hnj_bhCKeZW0bBiR0Uk6CJfhQ8CnIPHsvG4XFS90AhcqcjY4BpRTsxDE8hE0JvRqYxyVzqddbhO1n2tdCls3desVHU2sMXkO24RS-yo8Mpj__OMR ...
#  ResponseOutputMessage(id='msg_00f78a6ade944410006a5cb936670481a0a424e10b68a6620a', content=[ResponseOutputText(annotations=[], text='PostgreSQL and SQL Fundamentals for Modern Applications', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase=None)]
#
# -------------------- [Text] --------------------
# PostgreSQL and SQL Fundamentals for Modern Applications

# %%
# NOTE: If there are missing variables, an unsuccessful response will be returned.
invalid_response = client.responses.create(
  prompt={
    "id": "pmpt_69b5969364808193a373d5e88c855e7a07c62bd6487ba98f",
    "version": "3",
    "variables": {
      # "description": "Базите данни са стандартният начин за използване на динамична информация в съвременните технологии, правейки ги неизменна част от почти всяко едно приложение. Интензивният курс по основи на базите данни ще запознаe с една от най-широко използваните системи за управление на бази данни (DBMS), използвани при разработката на съвременни информационни системи - PostgreSQL. Курсът обръща сериозно внимание на релационния модел, ER диаграмите (таблици и релационни връзки) и работата с езика SQL (извличане на данни, селекция, проекция, съединения, агрегация, групиране, промяна, изтриване и вмъкване). Предоставят се фундаментални знания за работа с функции, процедури, transactions и тригери. Този курс полага основите на работата с бази данни, правейки по-лесно използването им в реални приложения и разбирането на концепции като превръщане на база данни в обектно-ориентиран модел (ORM). Също така 30% от задачите на упражненията ще се решават с помощта на AI с цел да се стимулира използването на съвременни технологии за автоматизация на процеси, като същевременно се развиват умения за ефективно прилагане на AI инструменти в реални условия."
    }
  }
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /tmp/ipykernel_745/3818893991.py in <cell line: 0>()
#       1 # NOTE: If there are missing variables, an unsuccessful response will be returned.
# ----> 2 invalid_response = client.responses.create(
#       3   prompt={
#       4     "id": "pmpt_69b5969364808193a373d5e88c855e7a07c62bd6487ba98f",
#       5     "version": "2",
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/responses/responses.py in create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#    1001         timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1002     ) -> Response | Stream[ResponseStreamEvent]:
# -> 1003         return self._post(
#    1004             "/responses",
#    1005             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1330             method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331         )
# -> 1332         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1333
#    1334     def patch(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1103
#    1104                 log.debug("Re-raising status error")
# -> 1105                 raise self._make_status_error_from_response(err.response) from None
#    1106
#    1107             break
#
# NotFoundError: Error code: 404 - {'error': {'message': "Prompt with id 'pmpt_69b5969364808193a373d5e88c855e7a07c62bd6487ba98f' not found.", 'type': 'invalid_request_error', 'param': None, 'code': None}}
